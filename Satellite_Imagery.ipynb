# %%
pip install tqdm

# %%
#!/usr/bin/env python3
import os
import pandas as pd
import rasterio
from rasterio.windows import Window
from rasterio.warp import calculate_default_transform, reproject, Resampling
from shapely.geometry import Point, box
import numpy as np
from pathlib import Path
from tqdm import tqdm

def reproject_raster(src_path, dst_path, dst_crs='EPSG:3035'):
    """
    Reproject a raster to EPSG:3035 (or other specified CRS) and save as a new file.
    
    Parameters:
    -----------
    src_path : str
        Path to the source raster
    dst_path : str
        Path to save the reprojected raster
    dst_crs : str, default='EPSG:3035'
        Target CRS (default is EPSG:3035 as specified)
    """
    with rasterio.open(src_path) as src:
        # Calculate the ideal dimensions and transformation for the new raster
        transform, width, height = calculate_default_transform(
            src.crs, dst_crs, src.width, src.height, *src.bounds)
        
        # Update the metadata for the output file
        kwargs = src.meta.copy()
        kwargs.update({
            'crs': dst_crs,
            'transform': transform,
            'width': width,
            'height': height
        })
        
        # Create the reprojected raster
        with rasterio.open(dst_path, 'w', **kwargs) as dst:
            # Set up progress bar for reprojection bands
            band_pbar = tqdm(range(1, src.count + 1), desc="Reprojecting bands", unit="band")
            
            # Iterate through bands and reproject each one
            for i in band_pbar:
                reproject(
                    source=rasterio.band(src, i),
                    destination=rasterio.band(dst, i),
                    src_transform=src.transform,
                    src_crs=src.crs,
                    dst_transform=transform,
                    dst_crs=dst_crs,
                    resampling=Resampling.nearest
                )
    
    print(f"Reprojected raster saved to: {dst_path}")
    return dst_path

def clip_around_midpoints(raster_dir, csv_path, output_dir, pixel_buffer=7, target_crs='EPSG:3035'):
    """
    Process satellite imagery based on midpoints from a CSV file.
    
    1. Read all raster files in the directory
    2. Read the CSV with midpoints
    3. For each raster:
       - Reproject to EPSG:3035 if needed
       - For each midpoint, clip the raster around the midpoint if it overlaps
    
    Parameters:
    -----------
    raster_dir : str
        Directory containing satellite imagery files (.tif)
    csv_path : str
        Path to the CSV file containing midpoint coordinates
    output_dir : str
        Directory to save clipped images
    pixel_buffer : int, default=7
        Number of pixels to extend in each direction from the midpoint
    target_crs : str, default='EPSG:3035'
        Target CRS for reprojection
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Read the CSV file with midpoints
    print(f"Reading midpoints from: {csv_path}")
    df = pd.read_csv(csv_path)
    
    # Check if 'Midpoint' column exists
    if 'Midpoint' not in df.columns:
        raise ValueError("CSV file must contain a 'Midpoint' column with coordinates")
    
    print(f"Found {len(df)} midpoints in CSV file")
    
    # Function to parse the midpoint string to x, y coordinates
    def parse_midpoint(midpoint_str):
        # Assuming format like "POINT (x y)" or "x,y" or similar
        # This may need adjustment based on your actual midpoint format
        if isinstance(midpoint_str, str):
            if "POINT" in midpoint_str:
                # WKT format
                coords = midpoint_str.replace("POINT (", "").replace(")", "").split()
            elif "," in midpoint_str:
                # Comma-separated format
                coords = midpoint_str.split(",")
            else:
                # Space-separated format
                coords = midpoint_str.split()
            
            return float(coords[0]), float(coords[1])
        elif isinstance(midpoint_str, (list, tuple)) and len(midpoint_str) >= 2:
            # Already a list or tuple
            return float(midpoint_str[0]), float(midpoint_str[1])
        else:
            raise ValueError(f"Cannot parse midpoint: {midpoint_str}")
    
    # Get all raster files in the directory
    print(f"Scanning for raster files in: {raster_dir}")
    raster_files = list(Path(raster_dir).glob("*.tif"))
    
    if not raster_files:
        raise ValueError(f"No .tif files found in directory: {raster_dir}")
    
    print(f"Found {len(raster_files)} raster files")
    
    # Track overall statistics
    total_processed = 0
    total_skipped = idx = 0
    
    # Main progress bar for raster files
    for raster_path in tqdm(raster_files, desc="Processing raster files", unit="file"):
        raster_name = raster_path.stem
        
        with rasterio.open(raster_path) as src:
            # Check if reprojection is needed
            if src.crs is None or src.crs.to_string() != target_crs:
                print(f"CRS mismatch or not defined. Reprojecting raster to {target_crs}...")
                # Create a temporary file for the reprojected raster
                temp_reprojected = os.path.join(output_dir, f"temp_reprojected_{raster_name}.tif")
                reprojected_path = reproject_raster(str(raster_path), temp_reprojected, target_crs)
                # Reopen with the reprojected raster
                src = rasterio.open(reprojected_path)
                print("Reprojection complete.")
            
            # Get raster bounds as a shapely polygon
            raster_bounds = box(*src.bounds)
            
            # Set up progress bar for midpoints
            midpoint_desc = f"Processing midpoints for {raster_name}"
            midpoint_pbar = tqdm(df.iterrows(), total=len(df), desc=midpoint_desc, unit="point")
            
            # Process each midpoint
            for idx, row in midpoint_pbar:
                try:
                    # Parse the midpoint coordinates
                    x, y = parse_midpoint(row['Midpoint'])
                    
                    # Create a point geometry for the midpoint
                    midpoint = Point(x, y)
                    
                    # Get the midpoint ID or use index if not available
                    midpoint_id = row.get('id', idx) if 'id' in row else idx
                    
                    # Update progress bar description with current midpoint ID
                    midpoint_pbar.set_postfix(point_id=str(midpoint_id), refresh=True)
                    
                    # Check if midpoint overlaps with raster bounds
                    if midpoint.intersects(raster_bounds):
                        try:
                            # Convert geographic coordinates to pixel coordinates
                            py, px = src.index(x, y)
                            
                            # Define the window for clipping (bounding box)
                            window = Window(
                                px - pixel_buffer, 
                                py - pixel_buffer, 
                                pixel_buffer * 2 + 1,  # +1 to include the center pixel
                                pixel_buffer * 2 + 1
                            )
                            
                            # Check if window is within the image bounds
                            if (px - pixel_buffer >= 0 and py - pixel_buffer >= 0 and 
                                px + pixel_buffer < src.width and py + pixel_buffer < src.height):
                                
                                # Read the data in the window
                                clipped_data = src.read(window=window)
                                
                                # Update the output profile
                                out_profile = src.profile.copy()
                                out_profile.update({
                                    'height': window.height,
                                    'width': window.width,
                                    'transform': rasterio.windows.transform(window, src.transform)
                                })
                                
                                # Create output filename
                                output_filename = f"{midpoint_id}_{raster_name}.tif"
                                output_path = os.path.join(output_dir, output_filename)
                                
                                # Write the clipped image
                                with rasterio.open(output_path, 'w', **out_profile) as dst:
                                    dst.write(clipped_data)
                                
                                total_processed += 1
                            else:
                                # Midpoint is too close to image edge
                                total_skipped += 1
                        except Exception as e:
                            total_skipped += 1
                            tqdm.write(f"Error processing midpoint {midpoint_id}: {e}")
                    else:
                        # Midpoint does not overlap with raster
                        total_skipped += 1
                except Exception as e:
                    total_skipped += 1
                    tqdm.write(f"Error parsing midpoint at index {idx}: {e}")
            
            # Clean up temporary reprojected file if it was created
            if src.name != str(raster_path):
                src.close()
                if os.path.exists(src.name):
                    os.remove(src.name)
                    print(f"Removed temporary reprojected file: {src.name}")
    
    # Print summary statistics
    print("\nProcessing complete!")
    print(f"Total clips created: {total_processed}")
    print(f"Total midpoints skipped: {total_skipped}")
    print(f"Output directory: {output_dir}")

if __name__ == "__main__":
    # Input and output directories
    raster_dir = r"C:\SatelliteImagery"
    csv_path = r"C:\SatelliteImagery\Dataset_Malaga.csv"  # Update with your actual CSV path
    output_dir = r"C:\SatelliteImagery\clipped_outputs"
    
    # Set buffer size (pixels to extend in each direction from the midpoint)
    pixel_buffer = 7  # This will create 15x15 images (7 pixels on each side plus the center)
    
    # Target CRS
    target_crs = 'EPSG:3035'  # European projection as specified
    
    # Process the images
    clip_around_midpoints(raster_dir, csv_path, output_dir, pixel_buffer=pixel_buffer, target_crs=target_crs)
# Out:
# Reading midpoints from: C:\SatelliteImagery\Dataset_Malaga.csv
# Found 15987 midpoints in CSV file
# Scanning for raster files in: C:\SatelliteImagery
# Found 1 raster files
# Processing raster files:   0%|                                                                 | 0/1 [00:00<?, ?file/s]
# CRS mismatch or not defined. Reprojecting raster to EPSG:3035...
# Reprojecting bands:   0%|                                                                      | 0/8 [00:00<?, ?band/s]
# Reprojecting bands:  12%|███████▊                                                      | 1/8 [01:18<09:11, 78.72s/band]
# Reprojecting bands:  25%|███████████████▎                                             | 2/8 [04:23<14:06, 141.09s/band]
# Reprojecting bands:  38%|██████████████████████▉                                      | 3/8 [07:44<14:03, 168.68s/band]
# Reprojecting bands:  50%|██████████████████████████████▌                              | 4/8 [12:08<13:44, 206.02s/band]
# Reprojecting bands:  62%|██████████████████████████████████████▏                      | 5/8 [17:47<12:42, 254.11s/band]
# Reprojecting bands:  75%|█████████████████████████████████████████████▊               | 6/8 [23:40<09:35, 287.84s/band]
# Reprojecting bands:  88%|█████████████████████████████████████████████████████▍       | 7/8 [29:36<05:09, 309.86s/band]
# Reprojecting bands: 100%|█████████████████████████████████████████████████████████████| 8/8 [34:11<00:00, 256.46s/band]
# Reprojected raster saved to: C:\SatelliteImagery\clipped_outputs\temp_reprojected_Test1.tif
# Reprojection complete.
# Processing midpoints for Test1:   0%|                                                     | 0/15987 [00:00<?, ?point/s]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=0]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=1]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=2]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=3]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=4]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=5]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=6]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=7]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=8]
# Processing midpoints for Test1:   0%|                                         | 0/15987 [00:00<?, ?point/s, point_id=9]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=10]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=11]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=12]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=13]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=14]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=15]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=16]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=17]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=18]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=19]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=20]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=21]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=22]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=23]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=24]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=25]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=26]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=27]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=28]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=29]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=30]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=31]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=32]
# Processing midpoints for Test1:   0%|                                        | 0/15987 [00:00<?, ?point/s, point_id=33]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=33]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=34]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=35]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=36]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=37]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=38]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=39]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=40]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=41]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=42]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=43]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=44]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=45]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=46]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=47]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=48]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=49]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=50]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=51]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=52]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=53]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=54]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=55]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=56]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=57]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=58]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=59]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=60]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=61]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=62]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=63]
# Processing midpoints for Test1:   0%|                              | 34/15987 [00:00<00:52, 303.69point/s, point_id=64]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=64]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=65]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=66]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=67]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=68]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=69]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=70]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=71]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=72]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=73]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=74]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=75]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=76]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=77]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=78]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=79]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=80]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=81]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=82]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=83]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=84]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=85]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=86]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=87]
# Processing midpoints for Test1:   0%|                              | 65/15987 [00:00<01:10, 226.77point/s, point_id=88]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=88]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=89]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=90]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=91]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=92]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=93]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=94]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=95]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=96]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=97]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=98]
# Processing midpoints for Test1:   1%|▏                             | 89/15987 [00:00<01:12, 220.72point/s, point_id=99]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=100]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=101]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=102]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=103]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=104]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=105]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=106]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=107]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=108]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=109]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=110]
# Processing midpoints for Test1:   1%|▏                            | 89/15987 [00:00<01:12, 220.72point/s, point_id=111]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=111]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=112]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=113]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=114]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=115]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=116]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=117]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=118]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=119]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=120]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=121]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=122]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=123]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=124]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=125]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=126]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=127]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=128]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=129]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=130]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=131]
# Processing midpoints for Test1:   1%|▏                           | 112/15987 [00:00<01:19, 200.53point/s, point_id=132]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=132]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=133]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=134]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=135]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=136]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=137]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=138]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=139]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=140]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=141]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=142]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=143]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=144]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=145]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=146]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=147]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=148]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=149]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=150]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=151]
# Processing midpoints for Test1:   1%|▏                           | 133/15987 [00:00<01:23, 190.25point/s, point_id=152]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=152]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=153]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=154]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=155]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=156]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=157]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=158]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=159]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=160]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=161]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=162]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=163]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=164]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=165]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=166]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=167]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=168]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=169]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=170]
# Processing midpoints for Test1:   1%|▎                           | 153/15987 [00:00<01:24, 186.57point/s, point_id=171]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=171]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=172]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=173]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=174]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=175]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=176]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=177]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=178]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=179]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=180]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=181]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=182]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=183]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=184]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=185]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=186]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=187]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=188]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=189]
# Processing midpoints for Test1:   1%|▎                           | 172/15987 [00:00<01:27, 181.22point/s, point_id=190]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:00<01:28, 177.75point/s, point_id=190]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:00<01:28, 177.75point/s, point_id=191]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:00<01:28, 177.75point/s, point_id=192]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:00<01:28, 177.75point/s, point_id=193]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=194]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=195]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=196]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=197]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=198]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=199]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=200]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=201]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=202]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=203]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=204]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=205]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=206]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=207]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=208]
# Processing midpoints for Test1:   1%|▎                           | 191/15987 [00:01<01:28, 177.75point/s, point_id=209]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=209]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=210]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=211]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=212]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=213]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=214]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=215]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=216]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=217]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=218]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=219]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=220]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=221]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=222]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=223]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=224]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=225]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=226]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=227]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=228]
# Processing midpoints for Test1:   1%|▎                           | 210/15987 [00:01<01:29, 175.44point/s, point_id=229]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=229]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=230]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=231]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=232]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=233]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=234]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=235]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=236]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=237]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=238]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=239]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=240]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=241]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=242]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=243]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=244]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=245]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=246]
# Processing midpoints for Test1:   1%|▍                           | 230/15987 [00:01<01:29, 176.08point/s, point_id=247]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=247]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=248]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=249]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=250]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=251]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=252]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=253]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=254]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=255]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=256]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=257]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=258]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=259]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=260]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=261]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=262]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=263]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=264]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=265]
# Processing midpoints for Test1:   2%|▍                           | 248/15987 [00:01<01:31, 171.73point/s, point_id=266]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=266]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=267]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=268]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=269]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=270]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=271]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=272]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=273]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=274]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=275]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=276]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=277]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=278]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=279]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=280]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=281]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=282]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=283]
# Processing midpoints for Test1:   2%|▍                           | 267/15987 [00:01<01:31, 172.24point/s, point_id=284]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=284]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=285]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=286]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=287]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=288]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=289]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=290]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=291]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=292]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=293]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=294]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=295]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=296]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=297]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=298]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=299]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=300]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=301]
# Processing midpoints for Test1:   2%|▍                           | 285/15987 [00:01<01:34, 165.81point/s, point_id=302]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=302]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=303]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=304]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=305]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=306]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=307]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=308]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=309]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=310]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=311]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=312]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=313]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=314]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=315]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=316]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=317]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=318]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=319]
# Processing midpoints for Test1:   2%|▌                           | 303/15987 [00:01<01:32, 169.20point/s, point_id=320]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=320]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=321]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=322]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=323]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=324]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=325]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=326]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=327]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=328]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=329]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=330]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=331]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=332]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=333]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=334]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=335]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=336]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=337]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=338]
# Processing midpoints for Test1:   2%|▌                           | 321/15987 [00:01<01:33, 167.39point/s, point_id=339]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=339]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=340]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=341]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=342]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=343]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=344]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=345]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=346]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=347]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=348]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=349]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=350]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=351]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=352]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=353]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=354]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=355]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=356]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=357]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=358]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=359]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=360]
# Processing midpoints for Test1:   2%|▌                           | 340/15987 [00:01<01:30, 172.49point/s, point_id=361]
# Processing midpoints for Test1:   2%|▋                           | 362/15987 [00:01<01:26, 180.59point/s, point_id=361]
# Processing midpoints for Test1:   2%|▋                           | 362/15987 [00:01<01:26, 180.59point/s, point_id=362]
# Processing midpoints for Test1:   2%|▋                           | 362/15987 [00:01<01:26, 180.59point/s, point_id=363]
# Processing midpoints for Test1:   2%|▋                           | 362/15987 [00:01<01:26, 180.59point/s, point_id=364]
# Processing midpoints for Test1:   2%|▋                           | 362/15987 [00:01<01:26, 180.59point/s, point_id=365]
# Processing midpoints for Test1:   2%|▋                           | 362/15987 [00:01<01:26, 180.59point/s, point_id=366]
# Processing midpoints for Test1:   2%|▋                           | 362/15987 [00:02<01:26, 180.59point/s, point_id=367]
# Processing midpoints for Test1:   2%|▋                           | 362/15987 [00:02<01:26, 180.59point/s, point_id=368]
# ...
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=768]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=769]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=770]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=771]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=772]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=773]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=774]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=775]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=776]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=777]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=778]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=779]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=780]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=781]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=782]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=783]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=784]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=785]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=786]
# Processing midpoints for Test1:   5%|█▎                          | 769/15987 [00:04<01:23, 182.59point/s, point_id=787]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=787]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=788]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=789]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=790]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=791]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=792]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=793]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=794]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=795]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=796]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=797]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=798]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=799]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=800]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=801]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=802]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=803]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=804]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=805]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=806]
# Processing midpoints for Test1:   5%|█▍                          | 788/15987 [00:04<01:24, 178.82point/s, point_id=807]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=807]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=808]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=809]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=810]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=811]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=812]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=813]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=814]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=815]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=816]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=817]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=818]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=819]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=820]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=821]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=822]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=823]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=824]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=825]
# Processing midpoints for Test1:   5%|█▍                          | 808/15987 [00:04<01:25, 178.31point/s, point_id=826]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=826]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=827]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=828]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=829]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=830]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=831]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=832]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=833]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=834]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=835]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=836]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=837]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=838]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=839]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=840]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=841]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=842]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=843]
# Processing midpoints for Test1:   5%|█▍                          | 827/15987 [00:04<01:26, 175.61point/s, point_id=844]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=844]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=845]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=846]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=847]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=848]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=849]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=850]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=851]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=852]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=853]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=854]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=855]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=856]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=857]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=858]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=859]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=860]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=861]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=862]
# Processing midpoints for Test1:   5%|█▍                          | 845/15987 [00:04<01:28, 171.00point/s, point_id=863]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=863]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=864]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=865]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=866]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=867]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=868]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=869]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=870]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=871]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=872]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=873]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=874]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=875]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=876]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=877]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=878]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=879]
# Processing midpoints for Test1:   5%|█▌                          | 864/15987 [00:04<01:29, 169.51point/s, point_id=880]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=880]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=881]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=882]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=883]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=884]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=885]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=886]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=887]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=888]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:04<01:29, 169.55point/s, point_id=889]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:05<01:29, 169.55point/s, point_id=890]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:05<01:29, 169.55point/s, point_id=891]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:05<01:29, 169.55point/s, point_id=892]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:05<01:29, 169.55point/s, point_id=893]
# Processing midpoints for Test1:   6%|█▌                          | 881/15987 [00:05<01:29, 169.55point/s, point_id=894]
