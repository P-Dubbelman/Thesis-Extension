# %%
import os
import logging
import numpy as np
import rasterio
from rasterio import windows
from rasterio.warp import calculate_default_transform, reproject, Resampling
from shapely.geometry import box, Point
import geopandas as gpd
from tqdm import tqdm

def reproject_raster(src_path, dst_path, dst_crs):
    """
    Reproject a raster to a specified CRS.

    Parameters:
    - src_path (str): Path to source raster
    - dst_path (str): Path to save reprojected raster
    - dst_crs (str or rasterio.crs.CRS): Destination Coordinate Reference System

    Returns:
    - dict: Metadata of the reprojected raster
    """
    with rasterio.open(src_path) as src:
        # Applying transformation parameters for reprojection
        transform, width, height = calculate_default_transform(
            src.crs, dst_crs, src.width, src.height,
            *src.bounds
        )

        # Prepare metadata for the destination raster
        kwargs = src.meta.copy()
        kwargs.update({
            'crs': dst_crs,
            'transform': transform,
            'width': width,
            'height': height
        })

        # Prepare the destination raster
        with rasterio.open(dst_path, 'w', **kwargs) as dst:
            # Reprojecting the raster to the specified CRS
            for i in tqdm(range(1, src.count + 1), desc=f"Reprojecting bands of {os.path.basename(src_path)}"):
                src_array = src.read(i)
                dst_array = np.empty((height, width), dtype=src_array.dtype)

                reproject(
                    source=src_array,
                    destination=dst_array,
                    src_transform=src.transform,
                    src_crs=src.crs,
                    dst_transform=transform,
                    dst_crs=dst_crs,
                    resampling=Resampling.nearest
                )

                dst.write(dst_array, i)

        return kwargs

def clip_points_from_rasters(
    geojson_file,
    raster_folder,
    output_dir="cropped_outputs",
    pixel_buffer=7,
    reprojected_raster_dir=None
):
    """
    Clip raster images around specific points from a GeoJSON file,
    with automatic raster reprojection and progress tracking.

    Parameters:
    - geojson_file (str): Path to the input GeoJSON file containing points
    - raster_folder (str): Directory containing input raster files
    - output_dir (str, optional): Directory to save clipped raster images.
      Defaults to "cropped_outputs"
    - pixel_buffer (int, optional): Number of pixels to buffer around the point.
      Defaults to 7
    - reprojected_raster_dir (str, optional): Directory to save reprojected rasters.
      If None, uses a subdirectory in output_dir
    """
    # Configure logging
    logging.basicConfig(level=logging.INFO,
                        format='%(asctime)s - %(levelname)s - %(message)s')
    logger = logging.getLogger(__name__)

    # Create output directories
    os.makedirs(output_dir, exist_ok=True)

    # Reprojecting the raster to the specified CRS
    if reprojected_raster_dir is None:
        reprojected_raster_dir = os.path.join(output_dir, "reprojected_rasters")
    os.makedirs(reprojected_raster_dir, exist_ok=True)

    # Read the GeoJSON file
    try:
        gdf = gpd.read_file(geojson_file)
    except Exception as e:
        logger.error(f"Error reading GeoJSON file: {e}")
        raise

    # Ensure the GeoJSON has a defined Coordinate Reference System (CRS)
    if not gdf.crs:
        logger.warning("GeoJSON has no CRS. Assuming EPSG:4326 (WGS84).")
        gdf = gdf.set_crs('EPSG:4326')

    # Get the CRS of the GeoJSON
    geojson_crs = gdf.crs.to_string()
    logger.info(f"GeoJSON CRS: {geojson_crs}")

    # Reprojecting the raster to the specified CRS
    gdf_proj = gdf.to_crs(geojson_crs)

    # Track successfully processed and skipped points
    total_points = len(gdf_proj)
    processed_points = 0
    skipped_points = 0

    # Get list of TIFF files and wrap with tqdm for progress tracking
    tiff_files = [f for f in os.listdir(raster_folder) if f.endswith(".tif")]

    # Iterate through raster files with progress bar
    for raster_file in tqdm(tiff_files, desc="Processing Rasters"):
        # Construct full path to the raster file
        raster_path = os.path.join(raster_folder, raster_file)

        # Open the raster file
        try:
            with rasterio.open(raster_path) as src:
                # Reprojecting the raster to the specified CRS
                current_raster_crs = src.crs.to_string()
                logger.info(f"Raster {raster_file} CRS: {current_raster_crs}")

                # Reprojecting the raster to the specified CRS
                if current_raster_crs != geojson_crs:
                    # Reprojecting the raster to the specified CRS
                    reprojected_raster_path = os.path.join(
                        reprojected_raster_dir,
                        f"reprojected_{raster_file}"
                    )
                    logger.info(f"Reprojecting {raster_file} to {geojson_crs}")

                    try:
                        reproject_raster(
                            raster_path,
                            reprojected_raster_path,
                            geojson_crs
                        )
                        raster_path = reprojected_raster_path
                    except Exception as e:
                        logger.error(f"Failed to reproject {raster_file}: {e}")
                        continue

                # Reprojecting the raster to the specified CRS
                with rasterio.open(raster_path) as src:
                    # Create output subdirectory for this raster
                    output_subdir = os.path.join(output_dir, os.path.splitext(raster_file)[0])
                    os.makedirs(output_subdir, exist_ok=True)

                    # Create bounding box of the raster
                    bounds_geom = box(*src.bounds)

                    # Reprojecting the raster to the specified CRS
                    for idx, row in tqdm(gdf_proj.iterrows(),
                                         total=len(gdf_proj),
                                         desc=f"Extracting points from {raster_file}",
                                         leave=False):
                        point = row.geometry

                        # Skip if not a point or outside raster bounds
                        if not isinstance(point, Point) or not bounds_geom.contains(point):
                            skipped_points += 1
                            continue

                        # Convert geographic coordinates to pixel coordinates
                        try:
                            px, py = ~src.transform * (point.x, point.y)
                            px, py = int(px), int(py)
                        except Exception as e:
                            logger.warning(f"Could not convert point {idx} to pixel coordinates: {e}")
                            skipped_points += 1
                            continue

                        # Define window around the point
                        window = windows.Window(
                            px - pixel_buffer, py - pixel_buffer,
                            2 * pixel_buffer + 1, 2 * pixel_buffer + 1
                        )

                        # Skip if window is outside raster bounds
                        if (
                            window.col_off < 0 or window.row_off < 0 or
                            window.col_off + window.width > src.width or
                            window.row_off + window.height > src.height
                        ):
                            skipped_points += 1
                            continue

                        # Read data for the window
                        data = src.read(window=window)

                        # Applying transformation parameters for reprojection
                        crop_transform = windows.transform(window, src.transform)

                        # Create output path for this crop
                        crop_path = os.path.join(output_subdir, f"{idx}.tif")

                        # Writing the output data
                        try:
                            with rasterio.open(
                                crop_path, 'w',
                                driver='GTiff',
                                height=data.shape[1],
                                width=data.shape[2],
                                count=data.shape[0],
                                dtype=data.dtype,
                                crs=src.crs,
                                transform=crop_transform
                            ) as dst:
                                dst.write(data)
                            processed_points += 1
                        except Exception as e:
                            logger.error(f"Error writing crop for point {idx}: {e}")

        except Exception as e:
            logger.error(f"Error processing raster {raster_file}: {e}")

    # Log summary
    logger.info(f"Total points in GeoJSON: {total_points}")
    logger.info(f"Processed points: {processed_points}")
    logger.info(f"Skipped points: {skipped_points}")

# Example usage
if __name__ == "__main__":
    clip_points_from_rasters(
        geojson_file= r"C:\Aarde, Economie & Duurzaamheid\Scriptie Uitbreiding\Dataset_Malaga.geojson",
        raster_folder= r"C:\SatelliteImagery",
        output_dir= r"C:\SatelliteImagery\clipped_outputs",
        pixel_buffer= 7,  # This gives 15x15 crops (2*7 + 1)
        reprojected_raster_dir=None  # Will use a subdirectory in output_dir
    )
# Out:
# 2025-05-12 17:14:04,202 - INFO - GeoJSON CRS: EPSG:3035
# Processing Rasters:   0%|                                                                        | 0/1 [00:00<?, ?it/s]2025-05-12 17:14:04,442 - INFO - Raster Test1.tif CRS: EPSG:32630
# 2025-05-12 17:14:04,458 - INFO - Reprojecting Test1.tif to EPSG:3035
#
# Reprojecting bands of Test1.tif:   0%|                                                           | 0/8 [00:00<?, ?it/s]
# Reprojecting bands of Test1.tif:  12%|██████▍                                            | 1/8 [00:24<02:49, 24.22s/it]
# Reprojecting bands of Test1.tif:  25%|████████████▊                                      | 2/8 [01:36<05:13, 52.22s/it]
# Reprojecting bands of Test1.tif:  38%|███████████████████▏                               | 3/8 [03:30<06:42, 80.45s/it]
# Reprojecting bands of Test1.tif:  50%|█████████████████████████▌                         | 4/8 [04:54<05:28, 82.15s/it]
# Reprojecting bands of Test1.tif:  62%|███████████████████████████████▉                   | 5/8 [06:11<04:00, 80.03s/it]
# Reprojecting bands of Test1.tif:  75%|██████████████████████████████████████▎            | 6/8 [07:59<02:59, 89.84s/it]
# Reprojecting bands of Test1.tif:  88%|████████████████████████████████████████████▋      | 7/8 [09:12<01:24, 84.13s/it]
# Reprojecting bands of Test1.tif: 100%|███████████████████████████████████████████████████| 8/8 [10:31<00:00, 78.93s/it]
#
# Extracting points from Test1.tif:   0%|                                                      | 0/16114 [00:00<?, ?it/s]
# Extracting points from Test1.tif:   0%|                                              | 1/16114 [00:00<42:54,  6.26it/s]
# Extracting points from Test1.tif:   1%|▍                                          | 174/16114 [00:00<00:20, 793.01it/s]
# Extracting points from Test1.tif:   2%|▋                                          | 270/16114 [00:00<00:26, 598.62it/s]
# Extracting points from Test1.tif:   2%|▉                                          | 348/16114 [00:00<00:26, 601.26it/s]
# Extracting points from Test1.tif:   3%|█                                          | 416/16114 [00:00<00:33, 474.11it/s]
# Extracting points from Test1.tif:   4%|█▋                                         | 613/16114 [00:00<00:19, 777.10it/s]
# Extracting points from Test1.tif:   4%|█▉                                         | 723/16114 [00:01<00:18, 839.12it/s]
# Extracting points from Test1.tif:   5%|██▏                                        | 818/16114 [00:01<00:18, 817.70it/s]
# Extracting points from Test1.tif:   6%|██▍                                        | 908/16114 [00:01<00:27, 558.86it/s]
# Extracting points from Test1.tif:   7%|███                                       | 1178/16114 [00:01<00:15, 956.06it/s]
# Extracting points from Test1.tif:   8%|███▍                                      | 1304/16114 [00:03<01:19, 186.27it/s]
# Extracting points from Test1.tif:   9%|███▋                                      | 1393/16114 [00:04<01:44, 141.23it/s]
# Extracting points from Test1.tif:   9%|███▊                                      | 1457/16114 [00:06<02:25, 100.39it/s]
# Extracting points from Test1.tif:  10%|███▉                                      | 1534/16114 [00:06<01:56, 125.55it/s]
# Extracting points from Test1.tif:  10%|████▏                                     | 1588/16114 [00:06<01:52, 129.31it/s]
# Extracting points from Test1.tif:  10%|████▍                                     | 1682/16114 [00:07<01:21, 177.49it/s]
# Extracting points from Test1.tif:  11%|████▋                                     | 1794/16114 [00:07<00:57, 248.18it/s]
# Extracting points from Test1.tif:  12%|████▊                                     | 1860/16114 [00:07<00:54, 262.29it/s]
# Extracting points from Test1.tif:  12%|████▉                                     | 1916/16114 [00:07<00:48, 293.32it/s]
# Extracting points from Test1.tif:  15%|██████▏                                   | 2390/16114 [00:07<00:15, 883.78it/s]
# Extracting points from Test1.tif:  16%|██████▋                                   | 2542/16114 [00:08<00:23, 582.09it/s]
# Extracting points from Test1.tif:  16%|██████▉                                   | 2657/16114 [00:08<00:25, 524.31it/s]
# Extracting points from Test1.tif:  17%|███████▏                                  | 2749/16114 [00:08<00:24, 546.17it/s]
# Extracting points from Test1.tif:  20%|████████▎                                | 3269/16114 [00:08<00:10, 1190.10it/s]
# Extracting points from Test1.tif:  22%|█████████                                 | 3470/16114 [00:09<00:14, 867.05it/s]
# Extracting points from Test1.tif:  22%|█████████▍                                | 3625/16114 [00:09<00:19, 625.32it/s]
# Extracting points from Test1.tif:  25%|██████████▍                               | 4024/16114 [00:09<00:12, 989.79it/s]
# Extracting points from Test1.tif:  26%|██████████▉                               | 4216/16114 [00:10<00:15, 783.30it/s]
# Extracting points from Test1.tif:  28%|███████████▌                             | 4542/16114 [00:10<00:11, 1048.34it/s]
# Extracting points from Test1.tif:  29%|████████████▎                             | 4724/16114 [00:10<00:12, 940.36it/s]
# Extracting points from Test1.tif:  32%|█████████████                            | 5136/16114 [00:10<00:07, 1373.08it/s]
# Extracting points from Test1.tif:  33%|█████████████▌                           | 5353/16114 [00:10<00:07, 1402.81it/s]
# Extracting points from Test1.tif:  35%|██████████████▌                          | 5715/16114 [00:10<00:06, 1707.46it/s]
# Extracting points from Test1.tif:  37%|███████████████▍                          | 5936/16114 [00:13<00:30, 334.46it/s]
# Extracting points from Test1.tif:  38%|████████████████                          | 6139/16114 [00:13<00:23, 418.14it/s]
# Extracting points from Test1.tif:  39%|████████████████▍                         | 6309/16114 [00:13<00:22, 444.25it/s]
# Extracting points from Test1.tif:  41%|█████████████████                         | 6527/16114 [00:13<00:16, 572.50it/s]
# Extracting points from Test1.tif:  43%|██████████████████                        | 6949/16114 [00:13<00:09, 926.47it/s]
# Extracting points from Test1.tif:  45%|██████████████████▋                       | 7178/16114 [00:14<00:15, 574.36it/s]
# Extracting points from Test1.tif:  46%|███████████████████▏                      | 7347/16114 [00:14<00:13, 644.51it/s]
# Extracting points from Test1.tif:  47%|███████████████████▌                      | 7500/16114 [00:15<00:14, 581.33it/s]
# Extracting points from Test1.tif:  47%|███████████████████▊                      | 7620/16114 [00:15<00:13, 630.11it/s]
# Extracting points from Test1.tif:  49%|████████████████████▍                     | 7824/16114 [00:15<00:10, 785.19it/s]
# Extracting points from Test1.tif:  49%|████████████████████▋                     | 7953/16114 [00:16<00:21, 376.77it/s]
# Extracting points from Test1.tif:  50%|████████████████████▉                     | 8047/16114 [00:17<00:34, 233.42it/s]
# Extracting points from Test1.tif:  50%|█████████████████████▏                    | 8116/16114 [00:17<00:32, 242.93it/s]
# Extracting points from Test1.tif:  51%|█████████████████████▎                    | 8173/16114 [00:18<00:36, 219.59it/s]
# Extracting points from Test1.tif:  52%|█████████████████████▉                    | 8429/16114 [00:18<00:18, 413.05it/s]
# Extracting points from Test1.tif:  53%|██████████████████████▎                   | 8537/16114 [00:18<00:20, 372.49it/s]
# Extracting points from Test1.tif:  54%|██████████████████████▋                   | 8700/16114 [00:18<00:14, 495.04it/s]
# Extracting points from Test1.tif:  55%|██████████████████████▉                   | 8801/16114 [00:18<00:15, 476.25it/s]
# Extracting points from Test1.tif:  55%|███████████████████████▎                  | 8925/16114 [00:19<00:12, 558.92it/s]
# Extracting points from Test1.tif:  56%|███████████████████████▋                  | 9070/16114 [00:19<00:10, 690.23it/s]
# Extracting points from Test1.tif:  57%|███████████████████████▉                  | 9172/16114 [00:19<00:13, 532.70it/s]
# Extracting points from Test1.tif:  58%|████████████████████████▎                 | 9337/16114 [00:19<00:09, 702.35it/s]
# Extracting points from Test1.tif:  59%|████████████████████████▋                 | 9494/16114 [00:19<00:07, 836.02it/s]
# Extracting points from Test1.tif:  60%|█████████████████████████▏                | 9645/16114 [00:19<00:07, 904.07it/s]
# Extracting points from Test1.tif:  61%|█████████████████████████▍                | 9758/16114 [00:20<00:10, 631.58it/s]
# Extracting points from Test1.tif:  61%|█████████████████████████▋                | 9847/16114 [00:20<00:14, 419.49it/s]
# Extracting points from Test1.tif:  62%|█████████████████████████▊                | 9916/16114 [00:20<00:16, 378.66it/s]
# Extracting points from Test1.tif:  62%|██████████████████████████                | 9978/16114 [00:21<00:15, 408.52it/s]
# Extracting points from Test1.tif:  62%|█████████████████████████▌               | 10035/16114 [00:21<00:15, 402.94it/s]
# Extracting points from Test1.tif:  63%|█████████████████████████▊               | 10128/16114 [00:21<00:12, 484.58it/s]
# Extracting points from Test1.tif:  63%|█████████████████████████▉               | 10218/16114 [00:21<00:10, 537.72it/s]
# Extracting points from Test1.tif:  64%|██████████████████████████▏              | 10282/16114 [00:21<00:12, 470.82it/s]
# Extracting points from Test1.tif:  65%|██████████████████████████▍              | 10407/16114 [00:21<00:09, 596.77it/s]
# Extracting points from Test1.tif:  65%|██████████████████████████▋              | 10476/16114 [00:22<00:13, 408.88it/s]
# Extracting points from Test1.tif:  65%|██████████████████████████▊              | 10530/16114 [00:22<00:13, 425.18it/s]
# Extracting points from Test1.tif:  66%|███████████████████████████▏             | 10705/16114 [00:22<00:08, 649.29it/s]
# Extracting points from Test1.tif:  68%|███████████████████████████▋             | 10901/16114 [00:22<00:05, 906.78it/s]
# Extracting points from Test1.tif:  69%|███████████████████████████▋            | 11172/16114 [00:22<00:03, 1312.76it/s]
# Extracting points from Test1.tif:  70%|████████████████████████████▊            | 11330/16114 [00:22<00:05, 883.15it/s]
# Extracting points from Test1.tif:  72%|████████████████████████████▉           | 11676/16114 [00:22<00:03, 1302.62it/s]
# Extracting points from Test1.tif:  74%|██████████████████████████████▏          | 11849/16114 [00:23<00:05, 791.19it/s]
# Extracting points from Test1.tif:  75%|██████████████████████████████▏         | 12164/16114 [00:23<00:03, 1117.52it/s]
# Extracting points from Test1.tif:  77%|███████████████████████████████▍         | 12348/16114 [00:23<00:04, 790.45it/s]
# Extracting points from Test1.tif:  78%|███████████████████████████████▊         | 12490/16114 [00:24<00:05, 606.39it/s]
# Extracting points from Test1.tif:  78%|████████████████████████████████         | 12599/16114 [00:24<00:05, 597.27it/s]
# Extracting points from Test1.tif:  79%|████████████████████████████████▍        | 12755/16114 [00:24<00:04, 696.20it/s]
# Extracting points from Test1.tif:  80%|████████████████████████████████▋        | 12857/16114 [00:25<00:09, 350.52it/s]
# Extracting points from Test1.tif:  80%|████████████████████████████████▉        | 12932/16114 [00:25<00:08, 382.97it/s]
# Extracting points from Test1.tif:  81%|█████████████████████████████████        | 13007/16114 [00:25<00:07, 424.33it/s]
# Extracting points from Test1.tif:  82%|█████████████████████████████████▋       | 13243/16114 [00:25<00:04, 657.53it/s]
# Extracting points from Test1.tif:  83%|█████████████████████████████████▉       | 13344/16114 [00:26<00:06, 443.26it/s]
# Extracting points from Test1.tif:  85%|██████████████████████████████████▊      | 13677/16114 [00:26<00:03, 785.44it/s]
# Extracting points from Test1.tif:  86%|███████████████████████████████████▏     | 13817/16114 [00:26<00:03, 590.20it/s]
# Extracting points from Test1.tif:  87%|███████████████████████████████████▊     | 14055/16114 [00:27<00:02, 801.18it/s]
# Extracting points from Test1.tif:  88%|████████████████████████████████████     | 14194/16114 [00:27<00:04, 452.47it/s]
# Extracting points from Test1.tif:  89%|████████████████████████████████████▍    | 14297/16114 [00:28<00:06, 264.60it/s]
# Extracting points from Test1.tif:  89%|████████████████████████████████████▋    | 14401/16114 [00:28<00:05, 311.31it/s]
# Extracting points from Test1.tif:  90%|████████████████████████████████████▊    | 14478/16114 [00:29<00:04, 350.49it/s]
# Extracting points from Test1.tif:  90%|█████████████████████████████████████    | 14578/16114 [00:29<00:03, 417.15it/s]
# Extracting points from Test1.tif:  93%|██████████████████████████████████████   | 14952/16114 [00:29<00:01, 853.52it/s]
# Extracting points from Test1.tif:  94%|██████████████████████████████████████▍  | 15111/16114 [00:29<00:01, 863.58it/s]
# Extracting points from Test1.tif:  95%|██████████████████████████████████████▊  | 15250/16114 [00:29<00:00, 896.21it/s]
# Extracting points from Test1.tif:  95%|███████████████████████████████████████▏ | 15378/16114 [00:29<00:00, 958.21it/s]
# Extracting points from Test1.tif:  96%|███████████████████████████████████████▍ | 15504/16114 [00:30<00:01, 538.43it/s]
# Extracting points from Test1.tif:  98%|████████████████████████████████████████▏| 15802/16114 [00:30<00:00, 858.25it/s]
# Processing Rasters: 100%|███████████████████████████████████████████████████████████████| 1/1 [12:02<00:00, 722.93s/it]
# 2025-05-12 17:26:07,199 - INFO - Total points in GeoJSON: 16114
# 2025-05-12 17:26:07,208 - INFO - Processed points: 756
# 2025-05-12 17:26:07,208 - INFO - Skipped points: 15358
